# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.evaluation import evaluate_policy

# %%
env = gym.make("gym_snake:gym_snake/Snake-v0")

# %%
check_env(env, warn=True)

# %%
log_path = os.path.join('training', 'logs')

# %%
model = PPO("MultiInputPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=1000000)
# Out:
# Logging to training\logs\PPO_17
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 143      |
# |    ep_rew_mean     | 5.96     |
# | time/              |          |
# |    fps             | 1285     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 118         |
# |    ep_rew_mean          | 5.29        |
# | time/                   |             |
# |    fps                  | 769         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012445565 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.132       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0846      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 0.308       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 106         |
# |    ep_rew_mean          | 5.07        |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 3           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011408363 |
# |    clip_fraction        | 0.0984      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | -0.0994     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.115       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 0.397       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | 5.14        |
# | time/                   |             |
# |    fps                  | 704         |
# |    iterations           | 4           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009802647 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.298       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 0.57        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 104          |
# |    ep_rew_mean          | 5.18         |
# | time/                   |              |
# |    fps                  | 665          |
# |    iterations           | 5            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0067360844 |
# |    clip_fraction        | 0.074        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.153        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.344        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00779     |
# |    value_loss           | 0.672        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 92.7         |
# |    ep_rew_mean          | 4.92         |
# | time/                   |              |
# |    fps                  | 630          |
# |    iterations           | 6            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0074087493 |
# |    clip_fraction        | 0.0669       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.182        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.182        |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00645     |
# |    value_loss           | 0.683        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.7        |
# |    ep_rew_mean          | 5.22        |
# | time/                   |             |
# |    fps                  | 616         |
# |    iterations           | 7           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008218685 |
# |    clip_fraction        | 0.0893      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.0186      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.336       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 0.852       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90.3         |
# |    ep_rew_mean          | 5.47         |
# | time/                   |              |
# |    fps                  | 608          |
# |    iterations           | 8            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0093279965 |
# |    clip_fraction        | 0.0889       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.952       |
# |    explained_variance   | 0.193        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.483        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00971     |
# |    value_loss           | 0.92         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 84.2       |
# |    ep_rew_mean          | 5.44       |
# | time/                   |            |
# |    fps                  | 598        |
# |    iterations           | 9          |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.00604329 |
# |    clip_fraction        | 0.0692     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.966     |
# |    explained_variance   | 0.126      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.428      |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0059    |
# |    value_loss           | 0.851      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 83.9         |
# |    ep_rew_mean          | 5.92         |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 10           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0067012426 |
# |    clip_fraction        | 0.0808       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.923       |
# |    explained_variance   | -0.1         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.496        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00783     |
# |    value_loss           | 0.982        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.9        |
# |    ep_rew_mean          | 6.06        |
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 11          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.005862707 |
# |    clip_fraction        | 0.0643      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.889      |
# |    explained_variance   | -0.0305     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.576       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00691    |
# |    value_loss           | 1.28        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.5        |
# |    ep_rew_mean          | 5.96        |
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 12          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007624788 |
# |    clip_fraction        | 0.0812      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.84       |
# |    explained_variance   | 0.0565      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.598       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00847    |
# |    value_loss           | 1.09        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 78.8        |
# |    ep_rew_mean          | 6.01        |
# | time/                   |             |
# |    fps                  | 578         |
# |    iterations           | 13          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008623656 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.871      |
# |    explained_variance   | 0.0508      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.388       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 1.35        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 78           |
# |    ep_rew_mean          | 5.95         |
# | time/                   |              |
# |    fps                  | 578          |
# |    iterations           | 14           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0048796386 |
# |    clip_fraction        | 0.0637       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.865       |
# |    explained_variance   | 0.0215       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.577        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00504     |
# |    value_loss           | 1.39         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 77.7        |
# |    ep_rew_mean          | 6           |
# | time/                   |             |
# |    fps                  | 583         |
# |    iterations           | 15          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008349437 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.841      |
# |    explained_variance   | 0.179       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.452       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00804    |
# |    value_loss           | 1.17        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 77.5         |
# |    ep_rew_mean          | 6.14         |
# | time/                   |              |
# |    fps                  | 586          |
# |    iterations           | 16           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0055341707 |
# |    clip_fraction        | 0.0575       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.766       |
# |    explained_variance   | -0.0195      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.579        |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00703     |
# |    value_loss           | 1.28         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 74.5        |
# |    ep_rew_mean          | 6.08        |
# | time/                   |             |
# |    fps                  | 590         |
# |    iterations           | 17          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008697552 |
# |    clip_fraction        | 0.0906      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.786      |
# |    explained_variance   | 0.187       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.73        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00721    |
# |    value_loss           | 1.46        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 73.9        |
# |    ep_rew_mean          | 6.16        |
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 18          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.007936124 |
# |    clip_fraction        | 0.0771      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.773      |
# |    explained_variance   | 0.14        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.802       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00569    |
# |    value_loss           | 1.57        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 68.7        |
# |    ep_rew_mean          | 5.73        |
# | time/                   |             |
# |    fps                  | 598         |
# |    iterations           | 19          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.005713978 |
# |    clip_fraction        | 0.0654      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.771      |
# |    explained_variance   | 0.077       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.618       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00624    |
# |    value_loss           | 1.54        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 69.9        |
# |    ep_rew_mean          | 5.84        |
# | time/                   |             |
# |    fps                  | 597         |
# |    iterations           | 20          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009055665 |
# |    clip_fraction        | 0.0962      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.808      |
# |    explained_variance   | 0.0237      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.711       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 1.64        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 71.6         |
# |    ep_rew_mean          | 5.82         |
# | time/                   |              |
# |    fps                  | 597          |
# |    iterations           | 21           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0055708215 |
# |    clip_fraction        | 0.0692       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.792       |
# |    explained_variance   | 0.15         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.749        |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00509     |
# |    value_loss           | 1.5          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 75.4       |
# |    ep_rew_mean          | 5.88       |
# | time/                   |            |
# |    fps                  | 593        |
# |    iterations           | 22         |
# |    time_elapsed         | 75         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.00908535 |
# |    clip_fraction        | 0.0974     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.78      |
# |    explained_variance   | -0.0294    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.572      |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0105    |
# |    value_loss           | 1.4        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 76.2        |
# |    ep_rew_mean          | 5.74        |
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 23          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.010667351 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.816      |
# |    explained_variance   | 0.189       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.479       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00619    |
# |    value_loss           | 1.28        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 77.7        |
# |    ep_rew_mean          | 5.97        |
# | time/                   |             |
# |    fps                  | 596         |
# |    iterations           | 24          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008230966 |
# |    clip_fraction        | 0.0745      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.784      |
# |    explained_variance   | 0.0737      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.422       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00615    |
# |    value_loss           | 1.38        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 77           |
# |    ep_rew_mean          | 6.14         |
# | time/                   |              |
# |    fps                  | 596          |
# |    iterations           | 25           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0060515567 |
# |    clip_fraction        | 0.084        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.731       |
# |    explained_variance   | 0.18         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.864        |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00653     |
# |    value_loss           | 1.41         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 74.4       |
# |    ep_rew_mean          | 6.13       |
# | time/                   |            |
# |    fps                  | 594        |
# |    iterations           | 26         |
# |    time_elapsed         | 89         |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.00752684 |
# |    clip_fraction        | 0.0836     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.734     |
# |    explained_variance   | 0.142      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.658      |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.00752   |
# |    value_loss           | 1.47       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 74.1         |
# |    ep_rew_mean          | 6.28         |
# | time/                   |              |
# |    fps                  | 593          |
# |    iterations           | 27           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0074527124 |
# |    clip_fraction        | 0.0772       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.685       |
# |    explained_variance   | 0.134        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.727        |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00804     |
# |    value_loss           | 1.95         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 73.5         |
# |    ep_rew_mean          | 6.46         |
# | time/                   |              |
# |    fps                  | 591          |
# |    iterations           | 28           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0061287433 |
# |    clip_fraction        | 0.074        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.706       |
# |    explained_variance   | 0.187        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.684        |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00635     |
# |    value_loss           | 1.52         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 76.9        |
# |    ep_rew_mean          | 6.89        |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 29          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008562939 |
# |    clip_fraction        | 0.0981      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.669      |
# |    explained_variance   | 0.0471      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.349       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00882    |
# |    value_loss           | 1.7         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 78.3        |
# |    ep_rew_mean          | 7.14        |
# | time/                   |             |
# |    fps                  | 596         |
# |    iterations           | 30          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.010031588 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.668      |
# |    explained_variance   | 0.0108      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.582       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00949    |
# |    value_loss           | 1.68        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 78.3        |
# |    ep_rew_mean          | 7.04        |
# | time/                   |             |
# |    fps                  | 597         |
# |    iterations           | 31          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.009919578 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.661      |
# |    explained_variance   | 0.0858      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.569       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00733    |
# |    value_loss           | 1.84        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 76.2        |
# |    ep_rew_mean          | 6.83        |
# | time/                   |             |
# |    fps                  | 599         |
# |    iterations           | 32          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.010839155 |
# |    clip_fraction        | 0.0861      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 0.0888      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.772       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00379    |
# |    value_loss           | 1.62        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 75.2        |
# |    ep_rew_mean          | 6.74        |
# | time/                   |             |
# |    fps                  | 596         |
# |    iterations           | 33          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.009247059 |
# |    clip_fraction        | 0.088       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.72       |
# |    explained_variance   | 0.0705      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.811       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00532    |
# |    value_loss           | 1.77        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 74.5         |
# |    ep_rew_mean          | 6.7          |
# | time/                   |              |
# |    fps                  | 593          |
# |    iterations           | 34           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0060893362 |
# |    clip_fraction        | 0.0799       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.647       |
# |    explained_variance   | 0.0484       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.703        |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00545     |
# |    value_loss           | 1.78         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 74.7        |
# |    ep_rew_mean          | 6.87        |
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 35          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.009389426 |
# |    clip_fraction        | 0.094       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.657      |
# |    explained_variance   | -0.00628    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.56        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00601    |
# |    value_loss           | 1.5         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 78          |
# |    ep_rew_mean          | 7.02        |
# | time/                   |             |
# |    fps                  | 596         |
# |    iterations           | 36          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.008516533 |
# |    clip_fraction        | 0.0776      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.652      |
# |    explained_variance   | 0.0736      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.739       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00394    |
# |    value_loss           | 1.79        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 76.7        |
# |    ep_rew_mean          | 6.74        |
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 37          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.007529979 |
# |    clip_fraction        | 0.0955      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.674      |
# |    explained_variance   | 0.0427      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.466       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00544    |
# |    value_loss           | 1.54        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 75.5        |
# |    ep_rew_mean          | 6.62        |
# | time/                   |             |
# |    fps                  | 590         |
# |    iterations           | 38          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.008657591 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.671      |
# |    explained_variance   | 0.24        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.844       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00801    |
# |    value_loss           | 1.49        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 72.6        |
# |    ep_rew_mean          | 6.31        |
# | time/                   |             |
# |    fps                  | 589         |
# |    iterations           | 39          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.011550114 |
# |    clip_fraction        | 0.0886      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.609      |
# |    explained_variance   | -0.0159     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.6         |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00609    |
# |    value_loss           | 1.87        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 69.9         |
# |    ep_rew_mean          | 6.18         |
# | time/                   |              |
# |    fps                  | 589          |
# |    iterations           | 40           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0074750725 |
# |    clip_fraction        | 0.0903       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.617       |
# |    explained_variance   | 0.122        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.992        |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00395     |
# |    value_loss           | 1.68         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 73.1         |
# |    ep_rew_mean          | 6.27         |
# | time/                   |              |
# |    fps                  | 590          |
# |    iterations           | 41           |
# |    time_elapsed         | 142          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0074916533 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.648       |
# |    explained_variance   | 0.28         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.02         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00573     |
# |    value_loss           | 1.46         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 72.5        |
# |    ep_rew_mean          | 6.2         |
# | time/                   |             |
# |    fps                  | 591         |
# |    iterations           | 42          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.007903755 |
# |    clip_fraction        | 0.0894      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.66       |
# |    explained_variance   | 0.342       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.954       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0058     |
# |    value_loss           | 1.25        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 71.5        |
# |    ep_rew_mean          | 6.25        |
# | time/                   |             |
# |    fps                  | 589         |
# |    iterations           | 43          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.011181397 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.611      |
# |    explained_variance   | 0.225       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.795       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00711    |
# |    value_loss           | 1.94        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 65.7        |
# |    ep_rew_mean          | 5.82        |
# | time/                   |             |
# |    fps                  | 590         |
# |    iterations           | 44          |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.009289628 |
# |    clip_fraction        | 0.094       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.642      |
# |    explained_variance   | 0.0997      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.756       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00499    |
# |    value_loss           | 1.74        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 68.5        |
# |    ep_rew_mean          | 6.2         |
# | time/                   |             |
# |    fps                  | 587         |
# |    iterations           | 45          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.007573706 |
# |    clip_fraction        | 0.0877      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.671      |
# |    explained_variance   | 0.26        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.844       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00595    |
# |    value_loss           | 1.44        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 69.3        |
# |    ep_rew_mean          | 6.28        |
# | time/                   |             |
# |    fps                  | 585         |
# |    iterations           | 46          |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.009076608 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.604      |
# |    explained_variance   | 0.158       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.497       |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00718    |
# |    value_loss           | 1.63        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 70.5        |
# |    ep_rew_mean          | 6.59        |
# | time/                   |             |
# |    fps                  | 583         |
# |    iterations           | 47          |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.007718641 |
# |    clip_fraction        | 0.0837      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.607      |
# |    explained_variance   | 0.147       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.72        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00577    |
# |    value_loss           | 1.64        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 73.8        |
# |    ep_rew_mean          | 7.14        |
# | time/                   |             |
# |    fps                  | 583         |
# |    iterations           | 48          |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.008594168 |
# |    clip_fraction        | 0.0803      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.591      |
# |    explained_variance   | -0.0551     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.816       |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0063     |
# |    value_loss           | 2           |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 71.5        |
# |    ep_rew_mean          | 6.94        |
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 49          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.008436595 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.589      |
# |    explained_variance   | 0.073       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.861       |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00447    |
# |    value_loss           | 1.89        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 70.5        |
# |    ep_rew_mean          | 6.95        |
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 50          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.008586664 |
# |    clip_fraction        | 0.0832      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.607      |
# |    explained_variance   | 0.0601      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.519       |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00431    |
# |    value_loss           | 1.77        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 69.9        |
# |    ep_rew_mean          | 6.73        |
# | time/                   |             |
# |    fps                  | 578         |
# |    iterations           | 51          |
# |    time_elapsed         | 180         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.005419462 |
# |    clip_fraction        | 0.0863      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.594      |
# |    explained_variance   | 0.189       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02        |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0033     |
# |    value_loss           | 2.03        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 67.3        |
# |    ep_rew_mean          | 6.23        |
# | time/                   |             |
# |    fps                  | 577         |
# |    iterations           | 52          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.007697317 |
# |    clip_fraction        | 0.0957      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.62       |
# |    explained_variance   | 0.195       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.804       |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.00446    |
# |    value_loss           | 1.86        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 68.5       |
# |    ep_rew_mean          | 6.15       |
# | time/                   |            |
# |    fps                  | 579        |
# |    iterations           | 53         |
# |    time_elapsed         | 187        |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.00947195 |
# |    clip_fraction        | 0.0938     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.618     |
# |    explained_variance   | 0.173      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.984      |
# |    n_updates            | 570        |
# |    policy_gradient_loss | -0.00519   |
# |    value_loss           | 1.69       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 70.8       |
# |    ep_rew_mean          | 6.36       |
# | time/                   |            |
# |    fps                  | 580        |
# |    iterations           | 54         |
# |    time_elapsed         | 190        |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.00865946 |
# |    clip_fraction        | 0.0829     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.588     |
# |    explained_variance   | -0.0162    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.726      |
# |    n_updates            | 580        |
# |    policy_gradient_loss | -0.00355   |
# |    value_loss           | 1.87       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 73.9         |
# |    ep_rew_mean          | 6.55         |
# | time/                   |              |
# |    fps                  | 582          |
# |    iterations           | 55           |
# |    time_elapsed         | 193          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0071528093 |
# |    clip_fraction        | 0.0912       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.617       |
# |    explained_variance   | 0.0987       |
# |    learning_rate        | 0.0003       |
# ...
# |    policy_gradient_loss | -0.00852     |
# |    value_loss           | 2.71         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 205         |
# |    ep_rew_mean          | 21.4        |
# | time/                   |             |
# |    fps                  | 794         |
# |    iterations           | 472         |
# |    time_elapsed         | 1217        |
# |    total_timesteps      | 966656      |
# | train/                  |             |
# |    approx_kl            | 0.010589343 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.405      |
# |    explained_variance   | 0.221       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.748       |
# |    n_updates            | 4760        |
# |    policy_gradient_loss | -0.00684    |
# |    value_loss           | 2.07        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 191         |
# |    ep_rew_mean          | 19.5        |
# | time/                   |             |
# |    fps                  | 794         |
# |    iterations           | 473         |
# |    time_elapsed         | 1219        |
# |    total_timesteps      | 968704      |
# | train/                  |             |
# |    approx_kl            | 0.016773917 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.445      |
# |    explained_variance   | 0.163       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.431       |
# |    n_updates            | 4770        |
# |    policy_gradient_loss | -0.00863    |
# |    value_loss           | 1.8         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 190         |
# |    ep_rew_mean          | 19.3        |
# | time/                   |             |
# |    fps                  | 794         |
# |    iterations           | 474         |
# |    time_elapsed         | 1221        |
# |    total_timesteps      | 970752      |
# | train/                  |             |
# |    approx_kl            | 0.016408335 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.454      |
# |    explained_variance   | 0.014       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.25        |
# |    n_updates            | 4780        |
# |    policy_gradient_loss | -0.00772    |
# |    value_loss           | 2.42        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 192        |
# |    ep_rew_mean          | 19.5       |
# | time/                   |            |
# |    fps                  | 794        |
# |    iterations           | 475        |
# |    time_elapsed         | 1224       |
# |    total_timesteps      | 972800     |
# | train/                  |            |
# |    approx_kl            | 0.02574747 |
# |    clip_fraction        | 0.123      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.394     |
# |    explained_variance   | 0.104      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.864      |
# |    n_updates            | 4790       |
# |    policy_gradient_loss | -0.00783   |
# |    value_loss           | 1.63       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 194         |
# |    ep_rew_mean          | 19.7        |
# | time/                   |             |
# |    fps                  | 794         |
# |    iterations           | 476         |
# |    time_elapsed         | 1226        |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.018442504 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.379      |
# |    explained_variance   | 0.0247      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.324       |
# |    n_updates            | 4800        |
# |    policy_gradient_loss | -0.0059     |
# |    value_loss           | 1.53        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 194        |
# |    ep_rew_mean          | 19.8       |
# | time/                   |            |
# |    fps                  | 795        |
# |    iterations           | 477        |
# |    time_elapsed         | 1228       |
# |    total_timesteps      | 976896     |
# | train/                  |            |
# |    approx_kl            | 0.01003544 |
# |    clip_fraction        | 0.0975     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.378     |
# |    explained_variance   | 0.0396     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.854      |
# |    n_updates            | 4810       |
# |    policy_gradient_loss | -0.00403   |
# |    value_loss           | 1.75       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 182          |
# |    ep_rew_mean          | 18.4         |
# | time/                   |              |
# |    fps                  | 795          |
# |    iterations           | 478          |
# |    time_elapsed         | 1231         |
# |    total_timesteps      | 978944       |
# | train/                  |              |
# |    approx_kl            | 0.0142865125 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.388       |
# |    explained_variance   | -0.241       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.869        |
# |    n_updates            | 4820         |
# |    policy_gradient_loss | -0.00902     |
# |    value_loss           | 1.75         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 183         |
# |    ep_rew_mean          | 18.5        |
# | time/                   |             |
# |    fps                  | 795         |
# |    iterations           | 479         |
# |    time_elapsed         | 1233        |
# |    total_timesteps      | 980992      |
# | train/                  |             |
# |    approx_kl            | 0.012677578 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.394      |
# |    explained_variance   | 0.00998     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.1         |
# |    n_updates            | 4830        |
# |    policy_gradient_loss | -0.00629    |
# |    value_loss           | 2.28        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 187         |
# |    ep_rew_mean          | 19          |
# | time/                   |             |
# |    fps                  | 795         |
# |    iterations           | 480         |
# |    time_elapsed         | 1235        |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.010446325 |
# |    clip_fraction        | 0.0839      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.355      |
# |    explained_variance   | 0.0597      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.301       |
# |    n_updates            | 4840        |
# |    policy_gradient_loss | -0.00547    |
# |    value_loss           | 1.74        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 186         |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 795         |
# |    iterations           | 481         |
# |    time_elapsed         | 1238        |
# |    total_timesteps      | 985088      |
# | train/                  |             |
# |    approx_kl            | 0.011722927 |
# |    clip_fraction        | 0.0942      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.391      |
# |    explained_variance   | 0.142       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.465       |
# |    n_updates            | 4850        |
# |    policy_gradient_loss | -0.000143   |
# |    value_loss           | 1.42        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 191         |
# |    ep_rew_mean          | 19.9        |
# | time/                   |             |
# |    fps                  | 795         |
# |    iterations           | 482         |
# |    time_elapsed         | 1240        |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.014407472 |
# |    clip_fraction        | 0.0808      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.384      |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.824       |
# |    n_updates            | 4860        |
# |    policy_gradient_loss | -0.00405    |
# |    value_loss           | 1.76        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 197         |
# |    ep_rew_mean          | 20.8        |
# | time/                   |             |
# |    fps                  | 795         |
# |    iterations           | 483         |
# |    time_elapsed         | 1242        |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.012692371 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.378      |
# |    explained_variance   | 0.0448      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.531       |
# |    n_updates            | 4870        |
# |    policy_gradient_loss | -0.00686    |
# |    value_loss           | 1.46        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 196         |
# |    ep_rew_mean          | 20.7        |
# | time/                   |             |
# |    fps                  | 796         |
# |    iterations           | 484         |
# |    time_elapsed         | 1245        |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.016269391 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.359      |
# |    explained_variance   | 0.0445      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.576       |
# |    n_updates            | 4880        |
# |    policy_gradient_loss | -0.00682    |
# |    value_loss           | 1.65        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 195         |
# |    ep_rew_mean          | 20.6        |
# | time/                   |             |
# |    fps                  | 796         |
# |    iterations           | 485         |
# |    time_elapsed         | 1247        |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.014286205 |
# |    clip_fraction        | 0.0876      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.372      |
# |    explained_variance   | -0.034      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.271       |
# |    n_updates            | 4890        |
# |    policy_gradient_loss | -0.00314    |
# |    value_loss           | 2.25        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 193         |
# |    ep_rew_mean          | 20.3        |
# | time/                   |             |
# |    fps                  | 796         |
# |    iterations           | 486         |
# |    time_elapsed         | 1249        |
# |    total_timesteps      | 995328      |
# | train/                  |             |
# |    approx_kl            | 0.012684601 |
# |    clip_fraction        | 0.0853      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.428      |
# |    explained_variance   | -0.000943   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.39        |
# |    n_updates            | 4900        |
# |    policy_gradient_loss | -0.00443    |
# |    value_loss           | 1.62        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 193         |
# |    ep_rew_mean          | 20.3        |
# | time/                   |             |
# |    fps                  | 796         |
# |    iterations           | 487         |
# |    time_elapsed         | 1252        |
# |    total_timesteps      | 997376      |
# | train/                  |             |
# |    approx_kl            | 0.012714581 |
# |    clip_fraction        | 0.0831      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.394      |
# |    explained_variance   | 0.17        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06        |
# |    n_updates            | 4910        |
# |    policy_gradient_loss | -0.00717    |
# |    value_loss           | 2.09        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 203         |
# |    ep_rew_mean          | 21.3        |
# | time/                   |             |
# |    fps                  | 796         |
# |    iterations           | 488         |
# |    time_elapsed         | 1254        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.012932697 |
# |    clip_fraction        | 0.0818      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.397      |
# |    explained_variance   | 0.183       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.462       |
# |    n_updates            | 4920        |
# |    policy_gradient_loss | -0.0051     |
# |    value_loss           | 1.87        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 203         |
# |    ep_rew_mean          | 21.3        |
# | time/                   |             |
# |    fps                  | 796         |
# |    iterations           | 489         |
# |    time_elapsed         | 1256        |
# |    total_timesteps      | 1001472     |
# | train/                  |             |
# |    approx_kl            | 0.016806204 |
# |    clip_fraction        | 0.0935      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.388      |
# |    explained_variance   | -0.183      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.47        |
# |    n_updates            | 4930        |
# |    policy_gradient_loss | -0.00737    |
# |    value_loss           | 1.57        |
# -----------------------------------------

# %%
evaluate_policy(model, env, n_eval_episodes=5, render=True)
# Out:
# C:\Users\Utilisateur\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (12.240000146627427, 8.415129334427105)

# %%
env.close()

# %%
model_path = os.path.join("training", "models")

# %%
model.save(os.path.join(model_path, "PPO-1M"))
